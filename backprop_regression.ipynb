# %% [markdown]
# <a href="https://colab.research.google.com/github/Badri-lab/Deep-Learning/blob/main/backprop_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df=pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]], columns=['cgpa','profile_score','lpa'])
df.shape
# Out:
# (4, 3)
